# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"]=8,4
import warnings
warnings.filterwarnings("ignore")

# %%
fifa=pd.read_csv(r"C:\Users\sande\Downloads\FIFA.csv")
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa.shape
# Out:
# (18207, 89)

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.isnull().sum().sum()
# Out:
# 76984

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
fifa["Body Type"].value_counts() # Counts each number of occurences of unique values
# Out:
# Body Type
# Normal                 10595
# Lean                    6417
# Stocky                  1140
# Messi                      1
# C. Ronaldo                 1
# Neymar                     1
# Courtois                   1
# PLAYER_BODY_TYPE_25        1
# Shaqiri                    1
# Akinfenwa                  1
# Name: count, dtype: int64

# %%
fifa.dtypes
# Out:
# Unnamed: 0          int64
# ID                  int64
# Name               object
# Age                 int64
# Photo              object
#                    ...
# GKHandling        float64
# GKKicking         float64
# GKPositioning     float64
# GKReflexes        float64
# Release Clause     object
# Length: 89, dtype: object

# %%
x=fifa["Age"]
sns.set(style="whitegrid")
vis=sns.distplot(x,bins=10,kde=True)

# %%
x=fifa["Age"]
sns.displot(x,bins=10,kde=True)

# %%
x=fifa["Age"]
x=pd.Series(x,name="Age Variable")
sns.displot(x,bins=10,kde=True)

# %%
sns.histplot(y=fifa["Age"],bins=10,kde=True) # vertical visual
# Out:
# <Axes: xlabel='Count', ylabel='Age'>

# %%
x=fifa["Age"]
x=pd.Series(x,name="Age Variable")
sns.kdeplot(x)
# Out:
# <Axes: xlabel='Age Variable', ylabel='Density'>

# %%
x=fifa["Age"]
x=pd.Series(x,name="Age Variable")
sns.kdeplot(x,shade=True,color="g")
# Out:
# <Axes: xlabel='Age Variable', ylabel='Density'>

# %%
x=fifa["Age"]
sns.displot(x,rug=True,bins=10,color="r")

# %%
x=fifa["Age"]
x=pd.Series(x,name="Age Variable")
sns.distplot(x,rug=True,hist=False)
# Out:
# <Axes: xlabel='Age Variable', ylabel='Density'>

# %%
fifa["Preferred Foot"].nunique()
# Out:
# 2

# %%
fifa["Preferred Foot"].value_counts()
# Out:
# Preferred Foot
# Right    13948
# Left      4211
# Name: count, dtype: int64

# %%
sns.countplot(x="Preferred Foot",data=fifa,color="b")
# Out:
# <Axes: xlabel='Preferred Foot', ylabel='count'>

# %%
sns.countplot(x="Preferred Foot", hue="Real Face", data=fifa)
# Out:
# <Axes: xlabel='Preferred Foot', ylabel='count'>

# %%
fifa["Real Face"].nunique()
# Out:
# 2

# %%
sns.countplot(y="Preferred Foot",data=fifa)
# Out:
# <Axes: xlabel='count', ylabel='Preferred Foot'>

# %%
sns.catplot(x="Preferred Foot",kind="count", palette="ch:.25",data=fifa)

# %%
fifa["International Reputation"].nunique()
# Out:
# 5

# %%
fifa["International Reputation"].value_counts()
# Out:
# International Reputation
# 1.0    16532
# 2.0     1261
# 3.0      309
# 4.0       51
# 5.0        6
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,5))
sns.stripplot(x="International Reputation",y="Potential",data=fifa)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
f,ax=plt.subplots(figsize=(8,5))
sns.stripplot(x="International Reputation",y="Potential",data=fifa,jitter=0.01,palette="Set2")
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.stripplot(x="International Reputation",y="Potential",hue="Preferred Foot",data=fifa,jitter=0.02,dodge=True)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
f, ax = plt.subplots(figsize=(8, 6))
ax = sns.lineplot(x="Stamina", y="Strength", data=fifa)
plt.title("Fifa Data")
# Out:
# Text(0.5, 1.0, 'Fifa Data')

# %%
fifa["Stamina"]
# Out:
# 0        72.0
# 1        88.0
# 2        81.0
# 3        43.0
# 4        90.0
#          ...
# 18202    40.0
# 18203    43.0
# 18204    55.0
# 18205    40.0
# 18206    47.0
# Name: Stamina, Length: 18207, dtype: float64

# %%
fifa["Strength"]
# Out:
# 0        59.0
# 1        79.0
# 2        49.0
# 3        64.0
# 4        75.0
#          ...
# 18202    47.0
# 18203    67.0
# 18204    32.0
# 18205    48.0
# 18206    60.0
# Name: Strength, Length: 18207, dtype: float64

# %%
sns.boxplot(x=fifa["Potential"])
# Out:
# <Axes: xlabel='Potential'>

# %%
sns.boxplot(x="International Reputation",y="Potential",data=fifa)
plt.show()

# %%
sns.boxplot(x="International Reputation",y="Potential",hue="Preferred Foot",data=fifa)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
sns.violinplot(x=fifa["Potential"])
# Out:
# <Axes: xlabel='Potential'>

# %%
sns.violinplot(x="International Reputation",y="Potential",data=fifa)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.violinplot(x="International Reputation", y="Potential", hue="Preferred Foot", 
               data=fifa, palette="muted", split=True)
# Out:
# <Axes: xlabel='International Reputation', ylabel='Potential'>

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.pointplot(x="International Reputation", y="Potential", data=fifa)
plt.show()
