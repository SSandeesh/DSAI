# %% [markdown]
# # Day-32(20June)
# - Python Functions
#   - Inbuilt or Buiit-In funtions : print(),len(),max() ---
#   - Userdefined functions : with def keywords
# - Define the function once,call as many times you want
# - Funtions
#   - With Arg
#     - Formal Arg
#     - Actual Arg
#       - Positional Arg(Actual Arg)
#       - Default Arg
#       - Keyword Arg
#       - Variable length Arg
#
#   - Without Arg

# %%
# User Defined Function
def func():
    print("Hello")

# %%
def func():
    print("Hello")
func()
# Out:
# Hello

# %%
def func(): #without Arg
    print("Hello")
func()
func()
func()
# Out:
# Hello
# Hello
# Hello

# %%
def add(x,y): # here x,y are Formal args
    print(x+y)
add(3,8) # 3,8 are Actual Arg
# Out:
# 11

# %%
def add(x,y):
    c=x+y
    return c
add(3,11)
# Out:
# 14

# %%
def add(x,y): # Positional error
    print(x+y)
add(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 def add(x,y): # Positional error
#       2     print(x+y)
# ----> 3 add(3)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
def greet(): # No parameters
    return 45+18
greet()
# Out:
# 63

# %%
def add(x,y): 
    print(x+y)
add(33,10)
def greet():
    return 45+18
greet()
# Out:
# 43
# 63

# %%
def add(x,y): 
    print(x+y)
def greet():
    return 45+18
    
add(33,10)
greet()
# Out:
# 43
# 63

# %%
def add(x,y): 
    print(x+y)
def greet():
    return ("Good Morning")
    
greet()
add(2,3)
# Out:
# 5

# %%
def add(x,y): 
    print(x+y)
def greet():
    print("Good Morning")
    
greet()
add(40,5)
# Out:
# Good Morning
# 45
